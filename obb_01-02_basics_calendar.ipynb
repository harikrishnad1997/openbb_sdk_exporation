# %% [markdown]
# # 01.02 Basics: Calendar

# %% [markdown]
# ## Import

# %%
from openbb_terminal.sdk import openbb
import pandas
# Out:
# Forecasting Toolkit is disabled. To use the Forecasting features please install the toolkit following the instructions here: https://my.openbb.co/app/sdk/installation
# Portfolio Optimization Toolkit is disabled. To use the Optimization features please install the toolkit following the instructions here: https://my.openbb.co/app/sdk/installation

# %% [markdown]
# ## Help / Info
#
# > https://docs.openbb.co/sdk/reference/economy/events
#
# ```python
# openbb.economy.events(countries: Union[List[str], str] = "", start_date: Optional[str] = None, end_date: Optional[str] = None)
# ```

# %%
help(openbb.economy.events)
# Out:
# Help on get_economic_calendar in module openbb_terminal.economy.nasdaq_model object:
#
# class get_economic_calendar(builtins.object)
#  |  get_economic_calendar(countries: Union[List[str], str] = '', start_date: Optional[str] = None, end_date: Optional[str] = None) -> pandas.core.frame.DataFrame
#  |
#  |  Get economic calendar for countries between specified dates
#  |
#  |  Parameters
#  |  ----------
#  |  countries : [List[str],str]
#  |      List of countries to include in calendar.  Empty returns all
#  |  start_date : Optional[str]
#  |      Start date for calendar
#  |  end_date : Optional[str]
#  |      End date for calendar
#  |
#  |  Returns
#  |  -------
#  |  pd.DataFrame
#  |      Economic calendar
#  |
#  |  Examples
#  |  --------
#  |  Get todays economic calendar for the United States
#  |  >>> from openbb_terminal.sdk import openbb
#  |  >>> calendar = openbb.economy.events("united_states")
#  |
#  |  To get multiple countries for a given date, pass the same start and end date as well as
#  |  a list of countries
#  |  >>> calendars = openbb.economy.events(["united_states", "canada"], start_date="2022-11-18", end_date="2022-11-18")
#  |
#  |  Methods defined here:
#  |
#  |  __call__(self, *args: Any, **kwargs: Any) -> Any
#  |      Call self as a function.
#  |
#  |  __init__(self, name: str, trail: str, func: Callable) -> None
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  about(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {'countries': typing.Union[typing.List[str], str], '...
#  |
#  |  __defaults__ = None
#  |
#  |  __kwdefaults__ = None
#  |
#  |  __signature__ = <Signature (countries: Union[List[str], str] = '...ona...

# %% [markdown]
# ## Define variables

# %%
countries = ["United States","Canada", "United Kingdom", "Germany", "France", "Japan", "Australia","India"]

# %% [markdown]
# ## Plot dataset
#
# > Note: Add openbb function to a variable to to deliver the output into a DataFrame!

# %%
economic_calendar = openbb.economy.events( countries = countries)

# %%
economic_calendar
# Out:
#    Time (ET)         Country                                       Event  \
# 0      02:45          France                French Industrial Production
# 1      08:10   United States                               All Car Sales
# 2      08:10   United States                             All Truck Sales
# 3      08:15           India                            Bank Loan Growth
# 4      08:15           India                              Deposit Growth
# 5      08:15           India                            FX Reserves, USD
# 6      08:30   United States               Average Hourly Earnings (YoY)
# 7      08:30   United States                     Average Hourly Earnings
# 8      08:30   United States                        Average Weekly Hours
# 9      08:30   United States                         Government Payrolls
# 10     08:30   United States                      Manufacturing Payrolls
# 11     08:30   United States                            Nonfarm Payrolls
# 12     08:30   United States                          Participation Rate
# 13     08:30   United States                    Private Nonfarm Payrolls
# 14     08:30   United States                        U6 Unemployment Rate
# 15     08:30   United States                           Unemployment Rate
# 16     13:00   United States             U.S. Baker Hughes Oil Rig Count
# 17     13:00   United States           U.S. Baker Hughes Total Rig Count
# 18     16:30  United Kingdom          CFTC GBP speculative net positions
# 19     16:30   United States    CFTC Aluminium speculative net positions
# 20     16:30   United States       CFTC Copper speculative net positions
# 21     16:30   United States         CFTC Corn speculative net positions
# 22     16:30   United States    CFTC Crude Oil speculative net positions
# 23     16:30   United States         CFTC Gold speculative net positions
# 24     16:30   United States   CFTC Nasdaq 100 speculative net positions
# 25     16:30   United States  CFTC Natural Gas speculative net positions
# 26     16:30   United States      CFTC S&P 500 speculative net positions
# 27     16:30   United States       CFTC Silver speculative net positions
# 28     16:30   United States     CFTC Soybeans speculative net positions
# 29     16:30   United States        CFTC Wheat speculative net positions
# 30     16:30          Canada          CFTC CAD speculative net positions
# 31     16:30       Australia          CFTC AUD speculative net positions
# 32     16:30           Japan          CFTC JPY speculative net positions
#
#      Actual Consensus Previous        Date
# 0      0.8%      0.3%    -1.1%  2023-06-02
# 1     3.11M         -    3.28M  2023-06-02
# 2    11.93M         -   12.81M  2023-06-02
# 3     15.4%     15.6%    15.5%  2023-06-02
# 4     10.9%     10.3%    10.4%  2023-06-02
# 5   589.14B   595.62B  593.48B  2023-06-02
# 6      4.3%      4.3%     4.4%  2023-06-02
# 7      0.3%      0.4%     0.4%  2023-06-02
# 8      34.3      34.4     34.4  2023-06-02
# 9     56.0K         -    41.0K  2023-06-02
# 10      -2K        8K      10K  2023-06-02
# 11     339K      180K     294K  2023-06-02
# 12    62.6%     62.5%    62.6%  2023-06-02
# 13     283K      160K     253K  2023-06-02
# 14     6.7%      6.6%     6.6%  2023-06-02
# 15     3.7%      3.5%     3.4%  2023-06-02
# 16      555         -      570  2023-06-02
# 17      696         -      711  2023-06-02
# 18    13.2K         -    11.6K  2023-06-02
# 19     6.4K         -     6.4K  2023-06-02
# 20   -35.7K         -   -29.8K  2023-06-02
# 21   -20.4K         -   -62.3K  2023-06-02
# 22   162.6K         -   193.1K  2023-06-02
# 23   169.3K         -   160.7K  2023-06-02
# 24     8.5K         -    14.5K  2023-06-02
# 25  -106.2K         -  -112.3K  2023-06-02
# 26  -434.2K         -  -404.3K  2023-06-02
# 27    21.1K         -    22.0K  2023-06-02
# 28    29.8K         -    29.2K  2023-06-02
# 29   -94.0K         -   -86.3K  2023-06-02
# 30   -29.9K         -   -48.5K  2023-06-02
# 31   -44.1K         -   -49.1K  2023-06-02
# 32   -96.2K         -   -80.7K  2023-06-02

# %% [markdown]
# ## Manipulate data

# %%
# DataFrame.set_index(keys, drop=True, append=False, inplace=False, verify_integrity=False)
economic_calendar.set_index( keys = ['Time (ET)'], append = True, inplace = True)

# %%
events_at_specific_time = economic_calendar.filter(like = "08:30", axis = 0)
events_at_specific_time
# Out:
#                     Country                          Event Actual Consensus  \
#    Time (ET)
# 6  08:30      United States  Average Hourly Earnings (YoY)   4.3%      4.3%
# 7  08:30      United States        Average Hourly Earnings   0.3%      0.4%
# 8  08:30      United States           Average Weekly Hours   34.3      34.4
# 9  08:30      United States            Government Payrolls  56.0K         -
# 10 08:30      United States         Manufacturing Payrolls    -2K        8K
# 11 08:30      United States               Nonfarm Payrolls   339K      180K
# 12 08:30      United States             Participation Rate  62.6%     62.5%
# 13 08:30      United States       Private Nonfarm Payrolls   283K      160K
# 14 08:30      United States           U6 Unemployment Rate   6.7%      6.6%
# 15 08:30      United States              Unemployment Rate   3.7%      3.5%
#
#              Previous        Date
#    Time (ET)
# 6  08:30         4.4%  2023-06-02
# 7  08:30         0.4%  2023-06-02
# 8  08:30         34.4  2023-06-02
# 9  08:30        41.0K  2023-06-02
# 10 08:30          10K  2023-06-02
# 11 08:30         294K  2023-06-02
# 12 08:30        62.6%  2023-06-02
# 13 08:30         253K  2023-06-02
# 14 08:30         6.6%  2023-06-02
# 15 08:30         3.4%  2023-06-02

# %%
event_impact_high = ['Average Hourly Earnings (YoY)	', 'Average Weekly Hours', 'Participation Rate', 'U6 Unemployment Rate'] 

economic_calendar[economic_calendar['Event'].isin(event_impact_high)]
# Out:
#                     Country                 Event Actual Consensus Previous  \
#    Time (ET)
# 8  08:30      United States  Average Weekly Hours   34.3      34.4     34.4
# 12 08:30      United States    Participation Rate  62.6%     62.5%    62.6%
# 14 08:30      United States  U6 Unemployment Rate   6.7%      6.6%     6.6%
#
#                     Date
#    Time (ET)
# 8  08:30      2023-06-02
# 12 08:30      2023-06-02
# 14 08:30      2023-06-02

# %%
event_impact_high_keywords = ['GDP', 'PCE', 'JOLTs', 'Job', 'PMI','Hours','U6']

# %%
# Check if keywords exist in dataframe
check_if_keyword_exists_bool = [ economic_calendar['Event'].str.contains(item).any() for item in event_impact_high_keywords ] # constructor
check_if_keyword_exists_bool
# Out:
# [False, False, False, False, False, True, True]

# %%
check_if_keyword_exists_sum = [ economic_calendar['Event'].str.contains(item).sum() for item in event_impact_high_keywords ] # constructor
check_if_keyword_exists_sum
# Out:
# [0, 0, 0, 0, 0, 1, 1]

# %%
[ economic_calendar[economic_calendar['Event'].str.contains(item)] for item in event_impact_high_keywords ]
# Out:
# [Empty DataFrame
#  Columns: [Country, Event, Actual, Consensus, Previous, Date]
#  Index: [],
#  Empty DataFrame
#  Columns: [Country, Event, Actual, Consensus, Previous, Date]
#  Index: [],
#  Empty DataFrame
#  Columns: [Country, Event, Actual, Consensus, Previous, Date]
#  Index: [],
#  Empty DataFrame
#  Columns: [Country, Event, Actual, Consensus, Previous, Date]
#  Index: [],
#  Empty DataFrame
#  Columns: [Country, Event, Actual, Consensus, Previous, Date]
#  Index: [],
#                     Country                 Event Actual Consensus Previous  \
#    Time (ET)
#  8 08:30      United States  Average Weekly Hours   34.3      34.4     34.4
#
#                     Date
#    Time (ET)
#  8 08:30      2023-06-02  ,
#                      Country                 Event Actual Consensus Previous  \
#     Time (ET)
#  14 08:30      United States  U6 Unemployment Rate   6.7%      6.6%     6.6%
#
#                      Date
#     Time (ET)
#  14 08:30      2023-06-02  ]

# %%
economic_calendar[economic_calendar['Event'].str.contains('|'.join(event_impact_high_keywords))]
# Out:
#                     Country                 Event Actual Consensus Previous  \
#    Time (ET)
# 8  08:30      United States  Average Weekly Hours   34.3      34.4     34.4
# 14 08:30      United States  U6 Unemployment Rate   6.7%      6.6%     6.6%
#
#                     Date
#    Time (ET)
# 8  08:30      2023-06-02
# 14 08:30      2023-06-02
